# %% [markdown]
# <a href="https://colab.research.google.com/github/dasolkim770/10804/blob/main/2_1_%EC%9E%85%EC%B6%9C%EB%A0%A5%ED%99%9C%EC%9A%A9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from datetime import datetime, date,time
print('<디데이(D-day) 프로그램>')
print ()
year = int(input('연도를 입력하세요: '))
month = int(input('월을 입력하세요: '))
day = int(input('일을 입력하세요: '))
dt4= date(year, month, day)
today = date.today()        # today =오늘 날짜 저장
dday = (dt4 - today).days   # dday = 두날짜 사이의 일수 계산하여 저장
print(f'{year}년 {month}월 {day}일은 {dday}일 남았습니다.')
# Out:
# <디데이(D-day) 프로그램>
#
# 연도를 입력하세요: 2029
# 월을 입력하세요: 1
# 일을 입력하세요: 1
# 2029년 1월 1일은 847일 남았습니다.
