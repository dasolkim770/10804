# %% [markdown]
# <a href="https://colab.research.google.com/github/dasolkim770/10804/blob/main/260909.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=6
b =1.5
c=1+ 2j
print(a, type(a))
print (b, type(b))
print (c, type(c))
print(a + 1, type(a + 1)) # 정수 +정수 =정수
print(a/ b, type(a / b)) #정수 / 실수 = 실수
print(a/ 2, type(a / 2)) # 정수 / 정수 = 실수
print(a // 2, type(a // 2)) # 정수 // 정수 = 정수
# Out:
# 6 <class 'int'>
# 1.5 <class 'float'>
# (1+2j) <class 'complex'>
# 7 <class 'int'>
# 4.0 <class 'float'>
# 3.0 <class 'float'>
# 3 <class 'int'>

# %%
a ='Hello'
b="
c =10
d=0
print (bool(a))
print(bool(b))
print(bool(c))
print(bool(d))
# Out:
#   File "/tmp/ipykernel_1970/1177793963.py", line 2
#     b="
#       ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
a= '100'
b = 'Pvthon'
c = 'name is "짱구"' #c='name is '짱구''(오류 발생)
d ='''name is "코난"'''
print(a, type(a))
print(b, type(b)
print (c, type(c))
print(d, type(d)
# Out:
#   File "/tmp/ipykernel_1970/2968591884.py", line 7
#     print (c, type(c))
#     ^
# SyntaxError: invalid syntax

# %%
a = 'hello '
b='world'
print(a+b)
print(a * 3)
print(a<b) #두 문자열을 사전순(알파벳순./.아스키코드값)으로.비교
print('h' in a)
print('wor'not in b)
# Out:
# hello world
# hello hello hello
# True
# True
# False

# %%
# 연속된 부분의 문자열열을 슬라이싱 : 변수명[시작인덱스:종료인덱스스
a = 'hello python'
print(a[0:5])
print(a[6: ])
print(a[ :5])
print(a[6:-4])
print(a[0:9:2])
# Out:
# hello
# python
# hello
# py
# hlopt

# %%
jumin =input('주민등록번호 입력:')

print('연: 20' + jumin[0:2])
print('연: ' + jumin[2:4])
print('연: ' + jumin[4:6])
